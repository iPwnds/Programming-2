# %% [markdown]
# # Data analysis: Weather
# In the file `weather_dataset.csv` you find weather data for various cities. It is up to you to clean and analyse this data. Use the provided code fields under the tasks to write down your code.

# %% [markdown]
# Import the necessary packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Import the weather dataset into a DataFrame named `df_weather`
# * Inspect the DataFrame by showing the first 10 rows (do not use slicing for this).

# %%
#Import and inspect
df_weather = pd.read_csv('weather_dataset.csv')
df_weather.head(10)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
# 5  20000106      1                  3            0.85          1.0244
# 6  20000107      1                  8            0.84          1.0267
# 7  20000108      1                  4            0.79          1.0248
# 8  20000109      1                  8            0.88          1.0243
# 9  20000110      1                  8            0.91          1.0337
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
# 5                    0.56                 0.00             5.7
# 6                    0.20                 0.00             0.0
# 7                    0.54                 0.00             4.3
# 8                    0.11                 0.65             0.0
# 9                    0.06                 0.09             0.0
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# 1              3.6             2.7  ...                 0.5
# 2              2.2             0.1  ...                -1.0
# 3              3.9             0.5  ...                 2.5
# 4              6.0             3.8  ...                -1.8
# 5              4.2             1.9  ...                -0.6
# 6              4.7             1.8  ...                 1.7
# 7              5.6             4.1  ...                 3.5
# 8              4.6             3.8  ...                 3.3
# 9              2.4             1.4  ...                 0.0
#
#    STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                 0.7               1.6            0.97          1.0275
# 1                 2.0               2.0            0.99          1.0293
# 2                 2.8               3.4            0.91          1.0267
# 3                 4.6               4.9            0.95          1.0222
# 4                 2.9               3.6            0.95          1.0209
# 5                 4.0               3.4            0.92          1.0209
# 6                 4.1               2.8            0.96          1.0258
# 7                 6.4               3.6            0.97          1.0210
# 8                 5.1               3.0            0.91          1.0280
# 9                 5.5               1.9            0.94          1.0369
#
#    TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                    0.25                 0.04              8.5
# 1                    0.17                 0.16              7.9
# 2                    0.27                 0.00              8.1
# 3                    0.11                 0.44              8.6
# 4                    0.39                 0.04              8.0
# 5                    0.55                 0.20              7.1
# 6                    0.27                 0.00              6.0
# 7                    0.18                 0.14              8.2
# 8                    0.43                 0.02              5.6
# 9                    0.58                 0.04              1.8
#
#    TOURS_temp_min  TOURS_temp_max
# 0             7.2             9.8
# 1             6.6             9.2
# 2             6.6             9.6
# 3             6.4            10.8
# 4             6.4             9.5
# 5             3.5            10.7
# 6             3.3             8.8
# 7             5.3            11.0
# 8             3.7             7.6
# 9            -1.5             5.0
#
# [10 rows x 165 columns]

# %% [markdown]
# * Change the dates in the DATE column to pandas datetime objects.
# * Only include the rows with data from 2009

# %%
#datetime objects, year 2009
df_weather['DATE'] = pd.to_datetime(df_weather['DATE'], format='%Y%m%d')
df_weather = df_weather[df_weather['DATE'].dt.year == 2009]
df_weather
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3288 2009-01-01      1                  4            0.84          1.0284
# 3289 2009-01-02      1                  8            0.89          1.0262
# 3290 2009-01-03      1                  5            0.72          1.0263
# 3291 2009-01-04      1                  4            0.75          1.0239
# 3292 2009-01-05      1                  8            0.84          1.0197
# ...         ...    ...                ...             ...             ...
# 3648 2009-12-27     12                  7            0.80          1.0118
# 3649 2009-12-28     12                  7            0.82          1.0084
# 3650 2009-12-29     12                  7            0.92          1.0028
# 3651 2009-12-30     12                  8            0.92          0.9979
# 3652 2009-12-31     12                  7            0.93          0.9958
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 3288                    0.63                 0.00             7.1
# 3289                    0.07                 0.00             0.0
# 3290                    0.50                 0.00             2.9
# 3291                    0.62                 0.00             5.4
# 3292                    0.28                 0.05             0.0
# ...                      ...                  ...             ...
# 3648                    0.37                 0.18             2.3
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 3288              1.5             0.2  ...                -6.0
# 3289             -1.0            -1.8  ...                -8.1
# 3290             -3.1            -6.2  ...                -5.8
# 3291             -3.7            -6.5  ...               -10.8
# 3292             -4.1            -6.4  ...               -12.6
# ...               ...             ...  ...                 ...
# 3648              1.0            -3.9  ...                -7.7
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 3288                -1.9               4.9            0.92          1.0259
# 3289                -4.6               4.9            0.93          1.0245
# 3290                -2.7               6.0            0.79          1.0236
# 3291                -5.8               1.9            0.86          1.0231
# 3292                -8.3               2.0            0.92          1.0181
# ...                  ...               ...             ...             ...
# 3648                -2.7               4.6            0.84          1.0091
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 3288                    0.22                 0.00              0.6
# 3289                    0.08                 0.00             -0.4
# 3290                    0.69                 0.00             -0.1
# 3291                    0.68                 0.00             -2.4
# 3292                    0.18                 0.16             -4.4
# ...                      ...                  ...              ...
# 3648                    0.58                 0.08              4.6
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
#
#       TOURS_temp_min  TOURS_temp_max
# 3288            -0.5             1.7
# 3289            -1.1             0.4
# 3290            -1.4             1.1
# 3291            -5.3             0.5
# 3292            -6.9            -1.9
# ...              ...             ...
# 3648            -0.5             9.7
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
#
# [365 rows x 165 columns]

# %% [markdown]
# * Remove the rows with NaN values.

# %%
#NaN
df_weather = df_weather.dropna()

# %% [markdown]
# * Create 4 different DataFrames, one for each of the following cities: Basel, Oslo, Roma and Maastricht. Name them `df_Basel`, `df_Oslo`, `df_Roma` and `df_Maastricht` respectively.
# * Each dataframe should include the columns with the dates and months and the columns with the data of the corresponding city.

# %%
#New dataframes
city_dfs = {}
for city in ['BASEL', 'OSLO', 'ROMA', 'MAASTRICHT']:
    city_dfs[city] = df_weather[['DATE', 'MONTH'] + [column for column in df_weather.columns if city in column]]

df_Basel = city_dfs['BASEL']
df_Oslo = city_dfs['OSLO']
df_Roma = city_dfs['ROMA']
df_Maastricht = city_dfs['MAASTRICHT']
df_Maastricht
# Out:
#            DATE  MONTH  MAASTRICHT_cloud_cover  MAASTRICHT_wind_speed  \
# 3288 2009-01-01      1                       8                    1.4
# 3289 2009-01-02      1                       7                    2.8
# 3290 2009-01-03      1                       3                    2.2
# 3291 2009-01-04      1                       8                    4.5
# 3292 2009-01-05      1                       6                    5.1
# ...         ...    ...                     ...                    ...
# 3648 2009-12-27     12                       7                    8.0
# 3649 2009-12-28     12                       7                    4.0
# 3650 2009-12-29     12                       6                    3.6
# 3651 2009-12-30     12                       8                    4.2
# 3652 2009-12-31     12                       8                    3.3
#
#       MAASTRICHT_wind_gust  MAASTRICHT_humidity  MAASTRICHT_pressure  \
# 3288                   4.0                 0.98               1.0299
# 3289                   8.0                 0.94               1.0288
# 3290                   7.0                 0.90               1.0282
# 3291                   9.0                 0.81               1.0208
# 3292                  11.0                 0.95               1.0197
# ...                    ...                  ...                  ...
# 3648                  15.0                 0.85               1.0024
# 3649                  11.0                 0.89               1.0053
# 3650                   8.0                 0.92               0.9976
# 3651                   9.0                 0.94               0.9925
# 3652                   7.0                 0.98               0.9948
#
#       MAASTRICHT_global_radiation  MAASTRICHT_precipitation  \
# 3288                         0.11                      0.00
# 3289                         0.08                      0.00
# 3290                         0.61                      0.00
# 3291                         0.11                      0.02
# 3292                         0.14                      0.72
# ...                           ...                       ...
# 3648                         0.08                      0.09
# 3649                         0.10                      0.02
# 3650                         0.11                      1.07
# 3651                         0.10                      0.63
# 3652                         0.03                      0.16
#
#       MAASTRICHT_sunshine  MAASTRICHT_temp_mean  MAASTRICHT_temp_min  \
# 3288                  0.0                  -3.8                 -6.6
# 3289                  0.0                  -1.2                 -3.8
# 3290                  7.0                  -3.5                 -8.1
# 3291                  0.0                  -0.8                 -1.9
# 3292                  0.5                  -2.9                 -9.3
# ...                   ...                   ...                  ...
# 3648                  0.0                   3.3                  1.7
# 3649                  0.0                   2.6                 -0.5
# 3650                  0.0                   1.7                 -1.0
# 3651                  0.0                   6.8                  1.2
# 3652                  0.0                   0.0                 -1.1
#
#       MAASTRICHT_temp_max
# 3288                 -2.0
# 3289                  0.1
# 3290                  0.3
# 3291                  0.1
# 3292                 -0.9
# ...                   ...
# 3648                  4.8
# 3649                  4.1
# 3650                  8.4
# 3651                 10.1
# 3652                  1.3
#
# [365 rows x 13 columns]

# %% [markdown]
# ### Maastricht
# Plot a figure displaying following information of the temperature measurements over time done in Maastricht:
# * Temperature in °C is displayed on the y-axis
# * Mean temperature in orange
# * Max temperature in red
# * Min temperature in blue
# * Display a legend with appropriate labels, indicating which data is shown
# * Ensure proper axis labels and a title are included
# * On the x-axis, ensure there are indications for every month, labeled with the abbreviation of the month in English (Jan, Feb, March etc.)

# %%
#Maastricht
plt.figure(figsize=(15,5))
plt.plot(df_Maastricht['DATE'], df_Maastricht['MAASTRICHT_temp_min'], label='Minimum temp', color='blue')
plt.plot(df_Maastricht['DATE'], df_Maastricht['MAASTRICHT_temp_mean'], label='Mean temp', color='orange')
plt.plot(df_Maastricht['DATE'], df_Maastricht['MAASTRICHT_temp_max'], label='Maximum temp', color='red')
plt.xticks(ticks=[f'2009-{month:02}' for month in range(1, 13)], # ['2009-01', '2009-02', ...]
           labels = ['Jan', 'Feb', 'March', 'April', 'May', 'Jun', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

plt.legend()
plt.title("Temperature in Maastricht for 2009")
plt.xlabel("Date")
plt.ylabel("Temperature in Celsius")
# Out:
# Text(0, 0.5, 'Temperature in Celsius')

# %% [markdown]
# ### Mean temperatures
# Create a new graph and plot the mean temperatures over time of the cities for which you created seperate dataframes. Temperatures are in degrees Celcius and displayed on the y-axis.
# * Maastricht in orange
# * Roma in red
# * Basel in green
# * Oslo in blue
# * Display a legend with appropriate labels so it is clear what data is shown
# * Ensure proper axis labels and a title are included
# * On the x-axis, ensure indications for every month, labeled with the abbreviation of the month in English (Jan, Feb, March etc.)
# * Show a grid

# %%
#Mean temperatures
plt.figure(figsize=(15,5))
plt.plot(df_Maastricht['DATE'], df_Maastricht['MAASTRICHT_temp_mean'], label='Maastricht', color='orange')
plt.plot(df_Roma['DATE'], df_Roma['ROMA_temp_mean'], label='Roma', color='red')
plt.plot(df_Basel['DATE'], df_Basel['BASEL_temp_mean'], label='Basel', color='green')
plt.plot(df_Oslo['DATE'], df_Oslo['OSLO_temp_mean'], label='Oslo', color='blue')
plt.xticks(ticks=[f'2009-{month:02}' for month in range(1, 13)], # ['2009-01', '2009-02', ...]
           labels = ['Jan', 'Feb', 'March', 'April', 'May', 'Jun', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

plt.legend()
plt.title("Mean Temperature for 2009")
plt.xlabel("Date")
plt.ylabel("Temperature in Celsius")
plt.grid()

# %% [markdown]
# ___

# %% [markdown]
# Check your work thouroughly and ensure you did all the tasks.
# There are no tests provided for this data analysis exercise. Ensure you used the right names.

# %% [markdown]
# ___
